# %%
import requests
import json

API_KEY = "zrpJizLeTwQ3plXyhvV2RoBw"
SECRET_KEY = "ZdRKOqJzMEr5pZmJJnnmv29xcYkfAr2X"

# %%
def baidu_text2image(prompt):
        
    url = "https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/text2image/sd_xl?access_token=" + get_access_token()
    
    payload = json.dumps({
        "prompt": "pretty,high quality,Chinese ancient style",
        "negative_prompt": "low quality, ugly,modern",
        "size": "1024x1024",
        "n": 1,
        "steps": 20,
        "sampler_index": "Euler a"
    })
    headers = {
        'Content-Type': 'application/json',
        'Accept': 'application/json'
    }
    
    response = requests.request("POST", url, headers=headers, data=payload)
    
    print(response.text)
    print(response)
    return response
    

def get_access_token():
    """
    使用 AK，SK 生成鉴权签名（Access Token）
    :return: access_token，或是None(如果错误)
    """
    url = "https://aip.baidubce.com/oauth/2.0/token"
    params = {"grant_type": "client_credentials", "client_id": API_KEY, "client_secret": SECRET_KEY}
    return str(requests.post(url, params=params).json().get("access_token"))

# %%
prompt = "飞流直下三千尺,疑是银河落九天"
res = baidu_text2image(prompt)
# Out:
# {"id":"as-n3jeerq6sj","object":"image","created":1711856356,"data":[{"object":"image","b64_image":"...","index":1}],"usage":{"prompt_tokens":65,"total_tokens":65}}
# <Response [200]>

# %%
res = res.json()

# %%
res
# Out:
# {'id': 'as-n3jeerq6sj',
#  'object': 'image',
#  'created': 1711856356,
#  'data': [{'object': 'image',
#    'b64_image': '...',
#    'index': 1}],
#  'usage': {'prompt_tokens': 65, 'total_tokens': 65}}

# %%
res['data'][0]['b64_image']
# Out:
# '...'

# %%
import base64
from IPython.display import display
from PIL import Image
import io

# 假设这是你的Base64编码的图片字符串
b64_image = res['data'][0]['b64_image']  # 请替换为你的Base64字符串

# 对Base64编码的字符串进行解码
image_data = base64.b64decode(b64_image)

# 将二进制数据转换为图片对象
image = Image.open(io.BytesIO(image_data))

# 在Jupyter Notebook中显示图片
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024>
